# %%
# "Testing proves that your code works as it's supposed to in response
#   to all the input types it's designed to receive."

# "Every programmer must test their code often"

# this chapter will cover the unittest module
#   - building a test case
#   - checking for pass or fail
#   - testing functions and classes
#   - how many tests to run for a project

# %% [markdown]
# # Testing a Function

# %%
# example of a function to test

def get_formatted_name(first, last):
    """ Generate a neatly formatted full name. """
    full_name = f"{first} {last}"
    return full_name.title()

print("Enter 'q' at any time to quit.")
while True:
    first = input("\nPlease give me a first name: ")
    if first == 'q':
        break
    last = input("Please give me a last name: ")
    if last == 'q':
        break

    formatted_name = get_formatted_name(first, last)
    print(f"\tNeatly formatted name: {formatted_name}.")
# Out:
# Enter 'q' at any time to quit.
# 	Neatly formatted name: Janis Joplin.

# %%
# Unit Tests and Test Cases

# "A 'unit test' verifies that one specific aspect of a function's behavior
#   is correct."
# "A 'test case' is a collection of unit tests that together prove that 
#   a function behaves as it's supposed to, within the full range of
#   situations you expect it to handle."

# It's best to always aim for full coverage of cases, but addressing
#   critical behaviors is often enough for small projects.

# For larger projects with widespread use, aim for full coverage.

# %%
# A Passing Test

import unittest
from name_function import get_formatted_name_pass

# When naming a Class for testing, be sure to inlcude 'Test' in the name
class NamesTestCase(unittest.TestCase):
    """ Tests for the funtion """
    # This is effectively a child class of unittest.TestCase
    # This class inherits from the unittest.TestCase

    # no def __init__() ????
    # probably because this class doesn't have attributes and won't
    #   be called through a function call

    # Any method that starts with 'test_' will automatically run
    # when the Python file (this code) opens
    def test_first_last_name(self):
        """ Do names like 'Janis Joplin' work? """

        # inside 'test_' methods, we call the functions we want to test
        formatted_name = get_formatted_name_pass('janis', 'joplin')
        self.assertEqual(formatted_name, 'Janis Joplin')

        # .assert is a unittest specific method
        # "Assert methods verify that a resuilt you received matches
        #   the result you expected to receive."

    # I imagine that loops would greatly increase the coverage of tests

# unittest.main(argv=['first-arg-is-ignored'], exit=False)
    # the string 'first-arg-is-ignored' can be changed

if __name__ == '__main__':
    # unittest.main()

    # I think we should be able to call unittest.main() without the if statement
    # FWIU, the if statement is there just to be sure about something ???

    # We still need additional arguments for unittest.main()
    #   when running in Jupyter, however.

    # ===== taken from the internet =====
    #   to run the above 'if' code block in Jupyter, send the following args
    unittest.main(argv=['first-arg-is-ignored'], exit=False)

# """
# In the printed output, the dot '.' above the line '---' signifies
#     that a single test case passed.
# The 'OK' at the end signifies that all intended tests passed.
# """
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %%
# A Failing Test

# mostly same code as before except now we're loading a modified method
#   from the name_function
import unittest
from name_function import get_formatted_name_fail

class NamesTestCase(unittest.TestCase):
    """ Tests for the funtion """

    # Any method that starts with 'test_' will automatically run
    # when the Python file (this code) opens
    def test_first_last_name(self):
        """ Do names like 'Janis Joplin' work? """

        # inside the 'test_' functions we call functions we want to test
        formatted_name = get_formatted_name_fail('janis', 'joplin')
        self.assertEqual(formatted_name, 'Janis Joplin')

        # .assert is a unittest specific method
        # "Assert methods verify that a resuilt you received matches
        #   the result you expected to receive.

# unittest.main(argv=['first-arg-is-ignored'], exit=False)
    # the string 'first-arg-is-ignored' can be changed

if __name__ == '__main__':
    # unittest.main()

    # I think we should be able to call unittest.main() without the if statement
    # FWIU, the if statement is there just to be sure ???
    # We still need additional arguments when running in Jupyter, however.

    # ===== taken from the internet =====
    #   to run the above if code block in Jupyter, send the following args
    # ===================================
    unittest.main(argv=['first-arg-is-ignored'], exit=False)

# """ 
# The 'E' tells us that 1 test case failed. 

# The 'ERROR:' information below the '=====' line tells us specifically which
#     test failed.

# The informtion below the '-----' includes the standard traceback for errors
#  """
# Out:
# E
# ...
# ERROR: test_first_last_name (__main__.NamesTestCase)
# Do names like 'Janis Joplin' work?
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/tmp/ipykernel_13384/2201179499.py", line 17, in test_first_last_name
#     formatted_name = get_formatted_name_fail('janis', 'joplin')
# TypeError: get_formatted_name_fail() missing 1 required positional argument: 'last'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# FAILED (errors=1)

# %%
# Responding to a Failed Test

# Passing a test means that the function behaves correctly
# Failing a test means there's a error in the changes made to the function

# To modify the get_formatted_name_fail() function, make middle names optional

# mostly same code as before except now we're loading a modified method
#   from the name_function
import unittest
from name_function import get_formatted_name_corrected

class NamesTestCase(unittest.TestCase):
    """ Tests for the funtion """

    def test_first_last_name(self):
        """ Do names like 'Janis Joplin' work? """

        formatted_name = get_formatted_name_corrected('janis', 'joplin')
        self.assertEqual(formatted_name, 'Janis Joplin')

if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)

# ===== Personal NOTE ======
# At the moment, this still feels like a convuluted way to verify that
#   something fails. 
# At the moment, it would seem that I'm would gain the same insight by
#   simply performing trial and error
# I am waiting to reach a point where the workflow actually becomes
#   more efficient than just "seeing what happens"
# ===== ======
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %%
# Adding New Tests

# Let's add a new test specifically to test our function that accepts
#   a middle name

import unittest
from name_function import get_formatted_name_corrected

class NamesTestCase(unittest.TestCase):
    """ Tests for the funtion """

    def test_first_last_name(self):
        """ Do names like 'Janis Joplin' work? """

        formatted_name = get_formatted_name_corrected('janis', 'joplin')
        self.assertEqual(formatted_name, 'Janis Joplin')

    # Recall that methods for testing must start with 'with_'
    def test_first_last_middle_name(self):
        """ Do names like 'Woflgang Amadeus Mozart' work? """
        formatted_name = get_formatted_name_corrected(
            'woflgang', 'mozart', 'amadeus')
        self.assertEqual(formatted_name, 'Woflgang Amadeus Mozart')

if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.002s
#
# OK

# %% [markdown]
# # Personal Note: Libraries
# There are other Python libraries for performing test automation
# * **unittest test** (part of the python standard library)
# * **pytest** (incluced in anaconda)
# * other Python libraries have **library specific** testing functions

# %% [markdown]
# # Testing a Class

# %%
# "If you have passing tests for a class you're working on, you can
#   be confident that improvements you make to the class won't accidentally 
#   break its current behavior."

# Testing Classes is similar to testing Functions

# %%
# A Variety of Assert Methods - These can be found inside the unittest.TestCase class

# assertEqual(a, b)
    # check if a == b
# assertNotEqual(a, b)
    # check if a != b
# assertTrue(x)
    # check if x is True
# assertFalse(x)
    # check if x is False
# assertIn(item, list)
    # check if item is in list
# assertNotIn(item, list)
    # check if item is not in list

# %%
# A Class to Test

class AnonymousSurvey:
    """ Collect anonymous answers to a survey question. """

    def __init__(self, question):
        """ Store a question, and prepare to store responses. """
        self.question = question
        self.responses = []

    def show_question(self):
        """ Show survey question """
        print(self.question)

    def store_response(self, new_response):
        """ Store a single response to the survey. """
        self.responses.append(new_response)

    def show_results(self):
        """ Show all the response that have been given. """
        print("Survey results:")
        for repsonse in self.responses:
            print(f"- {response}")

# %%
# Using the class as intended

from survey import AnonymousSurvey as AnonSurv

# Defina a question, and make a survey.
question = "What programming langauges did you first learn?"
my_survey = AnonSurv(question)

# Show the question, and store responses to the question.
my_survey.show_question()
print("Enter 'q' at any time to quit.\n")
while True:
    response = input("Language: ")
    if response == 'q':
        break
    my_survey.store_response(response)

# Show the survey results.
print("\nThank you to everyeone who participated in the survey!")
my_survey.show_results()
# Out:
# What langauge did you first learn to code?
# Enter 'q' at any time to quit.
#
#
# Thank you to everyeone who participated in the survey!
# Survey results:
# - C++
# - MATLAB
# - Python
# - Arduino
# - Java
# - Processing
# - JavaScript
# - Autohotkey
# - HTML
# - CSS
# - LaTeX

# %%
# What if we only want to output unique values?

# What if we want each user to have the option of entering more than
#   one response per entry?
# We would have to create another class/method to handle this, which risks
#   altering the entire behavior of our Class

# %%
# Testing the AnonymousSurvey Class

import unittest
from survey import AnonymousSurvey as AnonSurv

class TestAnonymousSurvey(unittest.TestCase):
    """ Tests for the class AnonymousSurvey """
    # In this approach, we create an instance in each of our test
    
    def test_store_single_response(self):
        """ Test that a single response is stored properly. """
        question = "What programming langauges did you first learn?"
        my_survey = AnonSurv(question)
        my_survey.store_response('C++')

        # check if the information we want can be found inside the response
        self.assertIn('C++', my_survey.responses)

    def test_store_three_responses(self):
        """ Test that three individual responses are stored properly. """
        question = "What programming langauges did you first learn?"
        my_survey = AnonSurv(question)
        responses = ['C++', 'MATLAB', 'Python']
        for response in responses:
           my_survey.store_response(response)

        for response in responses:
            self.assertIn(response, my_survey.responses)
        # note that my_survey.responses is referring to the list inside
        #   the object/class we're trying to test.

if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)

# I imagine that I would have a separate .py file just for testing
# I guess that would be a more efficient workflow than just trial-and-error
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.002s
#
# OK

# %%
# The setUp() Method

# In a testing class, the setUp() method runs before the 'test_' methods

# "Any objects created in the setUp() method are then available in each
#   test method you write."

import unittest
from survey import AnonymousSurvey as AnonSurv

class TestAnonymousSurvey(unittest.TestCase):
    """ Tests for the class AnonymousSurvey """
    # In this approach, we create a single instance for all the methods

    def setUp(self):
        """ Create a survey and a test response for use in all test methods. """
        question = "What programming langauges did you first learn?"
        self.my_survey = AnonSurv(question)
        self.responses = ['C++', 'MATLAB', 'Python']
        # I think this is analogous to an __init__(self, ...)
        # But, I'm not sure how this setUp(self) is different from __init__(self, ...)
        # I think the main difference is that setUp() is for testing classes

        # I guess I have to go back to the idea that test classes
        #   won't go through function calls

        # Also, setUp() may be specific to the uniittest library
        # Other testing libraries may not have this

    def test_store_single_response(self):
        """ Test that a single response is stored properly. """
        self.my_survey.store_response(self.responses[0])
        self.assertIn(self.responses[0], self.my_survey.responses)

    def test_store_three_responses(self):
        """ Test that three individual responses are stored properly. """
        for response in self.responses:
            self.my_survey.store_response(response)
        for response in self.responses:
            self.assertIn(response, self.my_survey.responses)

if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.002s
#
# OK
